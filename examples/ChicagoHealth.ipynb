# %%
import math
import geopandas as gpd
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
import geoplot as gplt
import geoplot.crs as gcrs
import contextily as cx
import matplotlib.pyplot as plt
from GeoConformalizedExplainer import GeoConformalizedExplainer

# %%
data = pd.read_csv('../data/chicago_health_index.csv')

# %%
data
# Out:
#      fid  OBJECTID    Shape_Leng    Shape_Area  TRACTCE10      geoid10  \
# 0      1         1  22777.477721  2.119089e+07     842400  17031842400
# 1      2         2  16035.054986  8.947394e+06     840300  17031840300
# 2      3         3  15186.400644  1.230614e+07     841100  17031841100
# 3      4         4  10472.230301  6.731931e+06     841200  17031841200
# 4      5         5  14719.443307  1.246016e+07     838200  17031838200
# ..   ...       ...           ...           ...        ...          ...
# 786  787       797   7934.689058  3.494478e+06      71000  17031071000
# 787  788       798   7939.390589  3.500534e+06      71200  17031071200
# 788  789       799  11207.303381  7.761939e+06     130300  17031130300
# 789  790       800   8964.922819  4.284219e+06     292200  17031292200
# 790  791       801  10649.877951  7.101663e+06     630900  17031630900
#
#      commarea  ChldPvt14  EP_CROWD  EP_UNINSUR  ...  FACHANGE  PCRIMERT15  \
# 0          44       30.2       2.0        18.6  ...    0.3564      0.0752
# 1          59       38.9       4.8        25.2  ...    0.1196      0.0143
# 2          34       40.4       4.9        32.1  ...    0.8937      0.0583
# 3          31       39.5      13.2        30.9  ...    0.0653      0.0202
# 4          28        7.0       0.0        13.9  ...    0.4168      0.0410
# ..        ...        ...       ...         ...  ...       ...         ...
# 786         7        1.4       0.9         6.9  ...   -0.0765      0.0145
# 787         7        8.3       0.8         5.8  ...   -0.4038      0.0486
# 788        13       14.8       8.7        19.8  ...    0.4593      0.0124
# 789        29       56.2       8.4        20.0  ...    0.1443      0.0338
# 790        63       41.6      14.8        31.9  ...    0.0724      0.0150
#
#      VCRIMERT15  ForclRt  EP_MUNIT  EP_GROUPQ  SchHP_Mi  BrownF_Mi        lat  \
# 0        0.0605     0.00         6        0.0  0.323962   0.825032 -87.630038
# 1        0.0114     0.00         2        0.0  2.913039   0.833580 -87.681879
# 2        0.0476     0.00        42        0.1  1.534987   0.245875 -87.635095
# 3        0.0334     0.00         1        0.1  1.652188   0.531682 -87.683339
# 4        0.0361     0.00         4       48.2  0.714182   0.787289 -87.675076
# ..          ...      ...       ...        ...       ...        ...        ...
# 786      0.0030     2.04        20       42.6  0.607967   2.652024 -87.655908
# 787      0.0283     2.20        36        0.3  0.236924   2.571034 -87.646207
# 788      0.0051     5.63        12        0.0  0.412685   1.257997 -87.713388
# 789      0.0600    10.68         3        0.0  2.883582   0.240352 -87.715704
# 790      0.0139     8.36         8        0.4  1.837887   1.686962 -87.708363
#
#            lon
# 0    41.742473
# 1    41.832093
# 2    41.851004
# 3    41.855561
# 4    41.870414
# ..         ...
# 786  41.921700
# 787  41.921853
# 788  41.986558
# 789  41.856650
# 790  41.789810
#
# [791 rows x 54 columns]

# %%
data.shape
# Out:
# (791, 54)

# %%
health_index = data['HealthLit']
