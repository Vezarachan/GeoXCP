# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import geopandas as gpd
import geoplot as gplt
import geoplot.crs as gcrs

sns.set_theme(style="whitegrid")

# %% [markdown]
# ## Uniform Noise

# %% [markdown]
# ### X1 Only

# %%
noise_coverage_X1_only = pd.read_csv('./results_uniform_noise/results_multi_level_noise-X1_only.csv')

# %%
noise_coverage_X1_only
# Out:
#     Unnamed: 0  noise_level    mse_X1   rmse_X1     r2_X1        mse_X2  \
# 0            0            1  0.000138  0.011747  0.999990  7.026647e-27
# 1            1            5  0.003393  0.058248  0.999748  1.316905e-24
# 2            2           10  0.013206  0.114916  0.999018  4.452674e-24
# 3            3           20  0.051839  0.227681  0.996147  1.159603e-23
# 4            4           30  0.124137  0.352331  0.990772  9.639657e-24
# 5            5           40  0.216298  0.465078  0.983921  2.928196e-23
# 6            6           50  0.330431  0.574832  0.975437  8.832978e-24
# 7            7           60  0.475821  0.689798  0.964630  1.271935e-23
# 8            8           70  0.654328  0.808906  0.951360  1.043419e-23
# 9            9           80  0.848955  0.921388  0.936892  1.332041e-22
# 10          10           90  1.205108  1.097774  0.910417  4.373738e-22
# 11          11          100  1.311021  1.144998  0.902544  4.819814e-22
# ...

# %%
x = noise_coverage_X1_only['noise_level']
y1 = noise_coverage_X1_only['rmse_X1']
y2 = noise_coverage_X1_only['X1_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.style.use('default')
plt.rcParams['font.size'] = 12
l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X1', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X1', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_uniform_noise/noise_uniform_coverage_x1_only_x1.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
y1 = noise_coverage_X1_only['rmse_X2']
y2 = noise_coverage_X1_only['X2_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')
plt.rcParams['font.size'] = 12
l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X2', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X2', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_uniform_noise/noise_uniform_coverage_x1_only_x2.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### X2 Only

# %%
noise_coverage_X2_only = pd.read_csv('./results_uniform_noise/results_multi_level_noise-X2_only.csv')

# %%
x = noise_coverage_X2_only['noise_level']
y1 = noise_coverage_X2_only['rmse_X1']
y2 = noise_coverage_X2_only['X1_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X1', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X1', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_uniform_noise/noise_uniform_coverage_x2_only_x1.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
y1 = noise_coverage_X2_only['rmse_X2']
y2 = noise_coverage_X2_only['X2_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X2', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X2', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_uniform_noise/noise_uniform_coverage_x2_only_x2.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### X1 and X2

# %%
noise_coverage_X1_and_X2 = pd.read_csv('./results_uniform_noise/results_multi_level_noise-X1_and_X2.csv')

# %%
x = noise_coverage_X1_and_X2['noise_level']
y1 = noise_coverage_X1_and_X2['rmse_X1']
y2 = noise_coverage_X1_and_X2['X1_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X1', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X1', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_uniform_noise/noise_uniform_coverage_x1_and_x2_x1.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
y1 = noise_coverage_X1_and_X2['rmse_X2']
y2 = noise_coverage_X1_and_X2['X2_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X2', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X2', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_uniform_noise/noise_uniform_coverage_x1_and_x2_x2.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Constant

# %%
noise_coverage_constant_uniform = pd.read_csv('./results_uniform_noise/results_multi_level_noise-constant.csv')

# %%
x = noise_coverage_constant_uniform['noise_level']
y1 = noise_coverage_constant_uniform['rmse_X1']
y2 = noise_coverage_constant_uniform['X1_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X1', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X1', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_uniform_noise/noise_uniform_coverage_constant_uniform_x1.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
y1 = noise_coverage_constant_uniform['rmse_X2']
y2 = noise_coverage_constant_uniform['X2_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X2', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X2', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_uniform_noise/noise_uniform_coverage_constant_uniform_x2.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 2d Gaussian Noise

# %% [markdown]
# ### X1 Only

# %%
noise_coverage_X1_only = pd.read_csv('./results_gaussian_noise/result_x1.csv')

# %%
noise_coverage_X1_only
# Out:
#     Unnamed: 0  noise_level       mse      rmse        r2  X1_cover_mean  \
# 0            0            1  0.000219  0.014804  0.999984         1.0000
# 1            1            5  0.005479  0.074020  0.999593         1.0000
# 2            2           10  0.021916  0.148039  0.998371         1.0000
# 3            3           20  0.087662  0.296078  0.993484         1.0000
# 4            4           30  0.197240  0.444117  0.985338         1.0000
# 5            5           40  0.350649  0.592157  0.973934         0.9988
# 6            6           50  0.547890  0.740196  0.959272         0.9836
# 7            7           60  0.788961  0.888235  0.941352         0.9572
# 8            8           70  1.073864  1.036274  0.920174         0.9488
# 9            9           80  1.402598  1.184313  0.895737         0.9252
# 10          10           90  1.775163  1.332352  0.868042         0.9032
# 11          11          100  2.191559  1.480391  0.837089         0.8792
# ...

# %%
x = noise_coverage_X1_only['noise_level']
y1 = noise_coverage_X1_only['rmse']
y2 = noise_coverage_X1_only['X1_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X1', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X1', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_gaussian_noise/noise_gaussian_coverage_x1_only.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### X2 Only

# %%
noise_coverage_X2_only = pd.read_csv('./results_gaussian_noise/result_x2.csv')

# %%
noise_coverage_X2_only
# Out:
#     Unnamed: 0  noise_level       mse      rmse        r2  X1_cover_mean  \
# 0            0            1  0.000066  0.008133  0.999995            1.0
# 1            1            5  0.001654  0.040664  0.999876            1.0
# 2            2           10  0.006614  0.081328  0.999503            1.0
# 3            3           20  0.026457  0.162656  0.998011            1.0
# 4            4           40  0.105828  0.325313  0.992046            1.0
# 5            5           50  0.165357  0.406641  0.987571            1.0
# 6            6           60  0.238114  0.487969  0.982103            1.0
# 7            7           70  0.324099  0.569297  0.975640            1.0
# 8            8           80  0.423313  0.650625  0.968183            1.0
# 9            9           90  0.535756  0.731953  0.959731            1.0
# 10          10          100  0.661427  0.813281  0.950286            1.0
# 11          11          150  1.488210  1.219922  0.888143            1.0
# ...

# %%
x = noise_coverage_X2_only['noise_level']
y1 = noise_coverage_X2_only['rmse']
y2 = noise_coverage_X2_only['X2_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X2', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X2', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_gaussian_noise/noise_gaussian_coverage_x2_only.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### X1 And X2

# %%
noise_coverage_X1_and_X2 = pd.read_csv('./results_gaussian_noise/X1_X2result.csv')

# %%
noise_coverage_X1_and_X2
# Out:
#     Unnamed: 0  noise_level      mse1     rmse1      r2_1      mse2     rmse2  \
# 0            0            1  0.000219  0.014804  0.999984  0.000066  0.008133
# 1            1            5  0.005479  0.074020  0.999593  0.001654  0.040664
# 2            2           10  0.021916  0.148039  0.998371  0.006614  0.081328
# 3            3           20  0.087662  0.296078  0.993484  0.026457  0.162656
# 4            4           30  0.197240  0.444117  0.985338  0.059528  0.243984
# 5            5           40  0.350649  0.592157  0.973934  0.105828  0.325313
# 6            6           50  0.547890  0.740196  0.959272  0.165357  0.406641
# 7            7           60  0.788961  0.888235  0.941352  0.238114  0.487969
# 8            8           70  1.073864  1.036274  0.920174  0.324099  0.569297
# 9            9           80  1.402598  1.184313  0.895737  0.423313  0.650625
# 10          10           90  1.775163  1.332352  0.868042  0.535756  0.731953
# ...

# %%
x = noise_coverage_X1_and_X2['noise_level']
y1 = noise_coverage_X1_and_X2['rmse1']
y2 = noise_coverage_X1_and_X2['X1_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X1', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X1', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_gaussian_noise/noise_gaussian_coverage_x1_and_x2_x1.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
y1 = noise_coverage_X1_and_X2['rmse2']
y2 = noise_coverage_X1_and_X2['X2_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X2', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X2', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_gaussian_noise/noise_gaussian_coverage_x1_and_x2_x2.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Constant Gaussian

# %%
noise_coverage_constant_gaussian = pd.read_csv('./results_gaussian_noise/results_multi_level_noise-constant_gaussian.csv')

# %%
noise_coverage_constant_gaussian
# Out:
#     Unnamed: 0  noise_level        mse_X1       rmse_X1  r2_X1        mse_X2  \
# 0            0            1  6.974780e-30  2.640981e-15    1.0  6.943534e-30
# 1            1            5  6.592493e-30  2.567585e-15    1.0  6.560722e-30
# 2            2           10  6.994355e-30  2.644684e-15    1.0  7.298616e-30
# 3            3           20  6.749276e-30  2.597937e-15    1.0  6.785035e-30
# 4            4           40  6.969393e-30  2.639961e-15    1.0  7.138742e-30
# 5            5           50  6.574570e-30  2.564092e-15    1.0  6.938787e-30
# 6            6           60  6.664037e-30  2.581480e-15    1.0  7.202139e-30
# 7            7           70  6.628597e-30  2.574606e-15    1.0  6.809325e-30
# 8            8           80  6.986927e-30  2.643280e-15    1.0  7.554700e-30
# 9            9           90  7.415868e-30  2.723209e-15    1.0  7.570143e-30
# 10          10          100  6.648097e-30  2.578390e-15    1.0  6.818563e-30
# ...

# %%
x = noise_coverage_constant_gaussian['noise_level']
y1 = noise_coverage_constant_gaussian['rmse_X1']
y2 = noise_coverage_constant_gaussian['X1_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X1', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X1', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_gaussian_noise/noise_gaussian_coverage_constant_gaussian_x1.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
y1 = noise_coverage_constant_gaussian['rmse_X2']
y2 = noise_coverage_constant_gaussian['X2_cover_mean']

# %%
fig, ax = plt.subplots(figsize=(7,5))
# plt.style.use('default')

plt.rcParams['font.size'] = 12

l1, = ax.plot(x, y1, 's-', color='#ae282c', label='RMSE of X2', markersize=6, linewidth=3)
ax.set_xlabel('Noise Level')
ax.set_ylabel('RMSE', color='#ae282c')
ax.tick_params(axis='y', labelcolor='#ae282c')
ax.set_xticks(np.arange(0, 201, 50))

ax.grid(True, linestyle='-', alpha=0.5)

ax_ = ax.twinx()
l2, = ax_.plot(x, y2, 'o--', color='#2066a8', label='Coverage Rate of X2', markersize=6, linewidth=3)
ax_.set_ylabel('Coverage Rate', color='#2066a8')
ax_.tick_params(axis='y', labelcolor='#2066a8')

lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper center')

fig.tight_layout()
plt.savefig('./results_gaussian_noise/noise_gaussian_coverage_constant_gaussian_x2.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Noise Level VS. GeoUncertainty

# %%
noise_levels = [10, 20, 40, 50, 60, 70, 80, 90, 100, 150, 200]

noise_geo_uncertainty_x1_only = {}

for noise_level in noise_levels:
    df = pd.read_csv(f'./results_uniform_noise/results_{noise_level}_noise-uniform_X1_only.csv')
    geo_uncertainty = df['X1_geo_uncertainty'].values
    noise_geo_uncertainty_x1_only[noise_level] = geo_uncertainty

# %%
noise_geo_uncertainty_x1_only = pd.DataFrame(noise_geo_uncertainty_x1_only)

# %%
noise_geo_uncertainty_x1_only
# Out:
#            10        20        40        50        60        70        80   \
# 0     1.508096  1.481613  1.717109  1.655551  1.417170  1.706315  1.749944
# 1     1.508096  1.483941  1.717109  1.660404  1.417170  1.706315  1.761023
# 2     1.516521  1.489203  1.717109  1.661151  1.420533  1.706315  1.766130
# 3     1.521064  1.493591  1.717109  1.661151  1.420533  1.706315  1.773386
# 4     1.521441  1.499044  1.717109  1.661151  1.423946  1.706315  1.773386
# ...        ...       ...       ...       ...       ...       ...       ...
# 2495  1.714404  1.765010  1.965031  1.873725  1.672528  1.893695  2.099584
# 2496  1.714404  1.765010  1.965031  1.873725  1.672528  1.893695  2.099584
# 2497  1.714404  1.765010  1.965031  1.873725  1.672528  1.893695  2.099584
# 2498  1.714404  1.765010  1.965031  1.873725  1.672528  1.893695  2.099584
# 2499  1.721162  1.765010  1.965031  1.873725  1.672528  1.893695  2.099584
#
#            90        100       150       200
# ...

# %%
noise_geo_uncertainty_x1_only_ = noise_geo_uncertainty_x1_only.melt()
noise_geo_uncertainty_x1_only_.columns = ['noise_level', 'geo_uncertainty']

# %%
sns.set_theme(style='whitegrid')

sns.boxplot(noise_geo_uncertainty_x1_only_, x='noise_level', y='geo_uncertainty', linewidth=.75, color='#9fc8c8', fliersize=2,
                 flierprops={'markerfacecolor': '#568b87', 'linewidth': .02, 'alpha': 0.4, 'markeredgewidth': 0.02})

plt.xlabel('Noise Level')
plt.ylabel('GeoUncertainty of X1')

plt.savefig('./results_uniform_noise/boxplot_noise_geouncertainty_x1_only.pdf', dpi=300, bbox_inches='tight')

# %%
noise_levels = [10, 20, 40, 50, 60, 70, 80, 90, 100, 150, 200]

noise_geo_uncertainty_x2_only = {}

for noise_level in noise_levels:
    df = pd.read_csv(f'./results_uniform_noise/results_{noise_level}_noise-uniform_X2_only.csv')
    geo_uncertainty = df['X2_geo_uncertainty'].values
    noise_geo_uncertainty_x2_only[noise_level] = geo_uncertainty

# %%
noise_geo_uncertainty_x2_only = pd.DataFrame(noise_geo_uncertainty_x2_only)

# %%
noise_geo_uncertainty_x2_only_ = noise_geo_uncertainty_x2_only.melt()
noise_geo_uncertainty_x2_only_.columns = ['noise_level', 'geo_uncertainty']

# %%
sns.set_theme(style='whitegrid')

sns.boxplot(noise_geo_uncertainty_x2_only_, x='noise_level', y='geo_uncertainty', linewidth=.75, color='#9fc8c8', fliersize=2,
                 flierprops={'markerfacecolor': '#568b87', 'linewidth': .02, 'alpha': 0.4, 'markeredgewidth': 0.02})

plt.xlabel('Noise Level')
plt.ylabel('GeoUncertainty of X2')

plt.savefig('./results_uniform_noise/boxplot_noise_geouncertainty_x2_only.pdf', dpi=300, bbox_inches='tight')

# %%
noise_levels = [10, 20, 40, 50, 60, 70, 80, 90, 100, 150, 200]

noise_geo_uncertainty_X1_and_X2 = {}

for noise_level in noise_levels:
    df = pd.read_csv(f'./results_uniform_noise/results_{noise_level}_noise-uniform_X1_and_X2.csv')
    geo_uncertainty = df['X1_geo_uncertainty'].values
    noise_geo_uncertainty_X1_and_X2[noise_level] = geo_uncertainty

# %%
noise_geo_uncertainty_X1_and_X2 = pd.DataFrame(noise_geo_uncertainty_X1_and_X2)

# %%
noise_geo_uncertainty_X1_and_X2_ = noise_geo_uncertainty_X1_and_X2.melt()
noise_geo_uncertainty_X1_and_X2_.columns = ['noise_level', 'geo_uncertainty']

# %%
sns.set_theme(style='whitegrid')

sns.boxplot(noise_geo_uncertainty_X1_and_X2_, x='noise_level', y='geo_uncertainty', linewidth=.75, color='#9fc8c8', fliersize=2, flierprops={'markerfacecolor': '#568b87', 'linewidth': .02, 'alpha': 0.4, 'markeredgewidth': 0.02})

plt.xlabel('Noise Level')
plt.ylabel('GeoUncertainty of X1')

plt.savefig('./results_uniform_noise/boxplot_noise_geouncertainty_x1_and_x2+x1.pdf', dpi=300, bbox_inches='tight')

# %%
noise_levels = [10, 20, 40, 50, 60, 70, 80, 90, 100, 150, 200]

noise_geo_uncertainty_X1_and_X2 = {}

for noise_level in noise_levels:
    df = pd.read_csv(f'./results_uniform_noise/results_{noise_level}_noise-uniform_X1_and_X2.csv')
    geo_uncertainty = df['X2_geo_uncertainty'].values
    noise_geo_uncertainty_X1_and_X2[noise_level] = geo_uncertainty

# %%
noise_geo_uncertainty_X1_and_X2 = pd.DataFrame(noise_geo_uncertainty_X1_and_X2)

# %%
noise_geo_uncertainty_X1_and_X2_ = noise_geo_uncertainty_X1_and_X2.melt()
noise_geo_uncertainty_X1_and_X2_.columns = ['noise_level', 'geo_uncertainty']

# %%
sns.set_theme(style='whitegrid')

sns.boxplot(noise_geo_uncertainty_X1_and_X2_, x='noise_level', y='geo_uncertainty', linewidth=.75, color='#9fc8c8', fliersize=2, flierprops={'markerfacecolor': '#568b87', 'linewidth': .02, 'alpha': 0.4, 'markeredgewidth': 0.02})

plt.xlabel('Noise Level')
plt.ylabel('GeoUncertainty of X2')

plt.savefig('./results_uniform_noise/boxplot_noise_geouncertainty_x1_and_x2+x2.pdf', dpi=300, bbox_inches='tight')
